# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:38a6c264-d812-4d3d-974f-83522e6e4a23.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:8cf9f42e-c31b-46f5-b1e3-6e13c2cb873d.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# ![4-dslanguages.png](attachment:d73951b2-41e9-4716-8f72-8d7e45df730b.png)

# %% [markdown]
# Some of the most commonly used libraries used by Data Scientists include:
#     1. TensorFlow
#     2. SciPy
#     3. Matplotlib

# %% [markdown]
# ![5-dslibraries.png](attachment:e61f5299-1769-450d-8bdc-c0f830790ee7.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |Jupyter Notebooks|
# |JupyterLite|
# |Anaconda|

# %% [markdown]
# ![6-dstools.png](attachment:82dd914a-7364-4efd-8f4a-7220ad844614.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:471a57e9-8e39-4e24-ae48-9b33e7921693.png)

# %%
(3*4) + 5
# Out:
# 17

# %%
# This a simple arithmetic expression to mutiply then add integers

# %% [markdown]
# ![7-introarithmetic.png](attachment:5263bc8e-2533-42ce-b967-479879a3b237.png)

# %%
minutes = 200 
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %%
# This will convert 200 minutes to hours by diving by 60

# %% [markdown]
# ![9-hourstominute.png](attachment:7e4db6e0-80f6-4138-b84c-7c25ffe43bf0.png)

# %% [markdown]
# **Objectives**
# - Convert minutes to hours
# - Create a markdown cell with a table of Data Science tools
# - Create a markdown cell to list data science libraries

# %% [markdown]
# ![10-objectives.png](attachment:41b56337-e2b6-4af5-8cc3-4d329067c912.png)

# %% [markdown]
# ## Author
# Aadit Shah

# %% [markdown]
# ![11-authordetails.png](attachment:49697efd-fcd3-44af-b6fe-190888ba19fd.png)
